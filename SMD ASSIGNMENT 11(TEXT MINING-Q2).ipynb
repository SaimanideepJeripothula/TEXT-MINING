# %% [markdown]
# # ASSIGNMENT 11

# %% [markdown]
# # TEXT MINING

# %% [markdown]
# # Question-2

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/dp/B09TPBK46B/ref=sr_1_1?crid=200BZUREQDD4N&keywords=hp+laptop+monitor+extender+screen&qid=1676565328&sprefix=hp+laptop+monitor+extender+screen%2Caps%2C272&sr=8-1'
url
# Out:
# 'https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/dp/B09TPBK46B/ref=sr_1_1?crid=200BZUREQDD4N&keywords=hp+laptop+monitor+extender+screen&qid=1676565328&sprefix=hp+laptop+monitor+extender+screen%2Caps%2C272&sr=8-1'

# %%
header={'User-Agent':'mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/110.0.0.0 safari/537.36'}

# %%
cookie={}

# %%
def Searchasin(asin):
    url="https://www.amazon.in/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Searchreviews(review_link):
    url="https://www.amazon.in"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
data_asin = url.split("/dp/")[1]
data_asin =  data_asin.split("/")[0]

# %%
data_asin = [data_asin]

# %%
len(data_asin)
# Out:
# 1

# %%
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.in/dp/B09TPBK46B

# %%
pages=25

# %%
time=[]
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-date"}):
            time.append(i.text)
# Out:
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
print(len(time))
print(time)
# Out:
# 48
# ...

# %%
names=[]
for j in range(1):
     for k in range(5):
            response=Searchreviews(link[j]+'&pageNumber='+str(k))
            soup=BeautifulSoup(response.content)
            for i in soup.find_all("span",class_='a-profile-name'):
                names.append(i.text)
# Out:
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4

# %%
cust_name=[]
for i in range(0,len(names)):
    cust_name.append(names[i])
cust_name
# Out:
# ['michael',
#  'michael',
#  'Yogesh S. Rege',
#  'Jblakeley32',
#  'Amazon Customer',
#  'Amazon Customer',
#  'D Spencer',
#  'D Spencer',
#  'C Kelley',
#  'O. Smith',
#  'Jessie',
#  'Amazon Customer',
#  'miao',
#  'michael',
#  'michael',
#  'Yogesh S. Rege',
#  'Jblakeley32',
#  'Amazon Customer',
#  'Amazon Customer',
#  'D Spencer',
#  'D Spencer',
#  'C Kelley',
#  'O. Smith',
#  'Jessie',
#  'Amazon Customer',
#  'miao',
#  'Tata',
#  'Edream Wang',
#  'BigA',
#  'Guns&Cameras',
#  'Alex',
#  'SW',
#  'Aaron',
#  'Mia',
#  'ClaireChen',
#  'ClaireChen',
#  'Ze Di',
#  'Ze Di',
#  'CZ',
#  'CZ',
#  'M. Carter',
#  'Haiyi',
#  'min lu',
#  'min lu',
#  'Dave',
#  'MonaLIU',
#  'Renee D',
#  'yira',
#  'LYNN',
#  'DanChai',
#  'Amal D.',
#  'chicago',
#  'XIAOCHEN WU',
#  'ZYY',
#  'amazonaddict',
#  'Mike H',
#  'jiminglin',
#  'Connor B.',
#  'Connor B.']

# %%
len(cust_name)
# Out:
# 59

# %%
for j in range(0,6):
    cust_name.pop(0)
    cust_name.pop(0)
print(cust_name)
len(cust_name)
# Out:
# ['miao', 'michael', 'michael', 'Yogesh S. Rege', 'Jblakeley32', 'Amazon Customer', 'Amazon Customer', 'D Spencer', 'D Spencer', 'C Kelley', 'O. Smith', 'Jessie', 'Amazon Customer', 'miao', 'Tata', 'Edream Wang', 'BigA', 'Guns&Cameras', 'Alex', 'SW', 'Aaron', 'Mia', 'ClaireChen', 'ClaireChen', 'Ze Di', 'Ze Di', 'CZ', 'CZ', 'M. Carter', 'Haiyi', 'min lu', 'min lu', 'Dave', 'MonaLIU', 'Renee D', 'yira', 'LYNN', 'DanChai', 'Amal D.', 'chicago', 'XIAOCHEN WU', 'ZYY', 'amazonaddict', 'Mike H', 'jiminglin', 'Connor B.', 'Connor B.']
# 47

# %%
print(len(cust_name))
print(cust_name)
# Out:
# 47
# ['miao', 'michael', 'michael', 'Yogesh S. Rege', 'Jblakeley32', 'Amazon Customer', 'Amazon Customer', 'D Spencer', 'D Spencer', 'C Kelley', 'O. Smith', 'Jessie', 'Amazon Customer', 'miao', 'Tata', 'Edream Wang', 'BigA', 'Guns&Cameras', 'Alex', 'SW', 'Aaron', 'Mia', 'ClaireChen', 'ClaireChen', 'Ze Di', 'Ze Di', 'CZ', 'CZ', 'M. Carter', 'Haiyi', 'min lu', 'min lu', 'Dave', 'MonaLIU', 'Renee D', 'yira', 'LYNN', 'DanChai', 'Amal D.', 'chicago', 'XIAOCHEN WU', 'ZYY', 'amazonaddict', 'Mike H', 'jiminglin', 'Connor B.', 'Connor B.']

# %%
title=[]
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("a",{'data-hook':"review-title"}):
            title.append(i.text)
# Out:
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
review_title=[]
for i in range(0,len(title)):
    review_title.append(title[i])
review_title[:]=[titles.lstrip('\n') for titles in review_title]
review_title[:]=[titles.rstrip('\n') for titles in review_title]
review_title
# Out:
# []

# %%
reviews=[]
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews.append(i.text)
# Out:
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
review=[]
for i in range(0,len(reviews)):
    review.append(reviews[i])
review[:]=[rev.lstrip('\n') for rev in review]
review[:]=[rev.rstrip('\n') for rev in review]

# %%
print(len(review))
review
# Out:
# 48
# ...

# %%
ratings=[] 
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("i",{'data-hook':"review-star-rating"}):
            ratings.append(i.text)
# Out:
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
rating=[]
for i in range(len(ratings)):
    rating.append(int(float(ratings[i].split(" ")[0])))

# %%
len(rating)
# Out:
# 0

# %%
upvotes=[]
for j in range(1):
    for k in range(10):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"helpful-vote-statement"}):
            upvotes.append(i.text)
# Out:
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Extender-P2-Portable-Plug-Play-Speakers/product-reviews/B09TPBK46B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
len(upvotes)
# Out:
# 25

# %%
import pandas as pd
rev = {'TimeStamp':time,'ReviewTitle':review_title,'review':review,'ratings':rating}
data = pd.DataFrame.from_dict(rev,orient='index')
df=data.transpose()

# %%
df.head()
# Out:
#                                            TimeStamp ReviewTitle  \
# 0   Reviewed in the United States on 21 January 2023        None
# 1   Reviewed in the United States on 25 January 2023        None
# 2   Reviewed in the United States on 12 October 2022        None
# 3  Reviewed in the United States on 17 November 2022        None
# 4    Reviewed in the United States on 6 January 2023        None
#
#                                               review ratings
# 0  First let me start this by saying I am not the...    None
# 1  The monitors connect consistently well to my D...    None
# 2  This is an awesome product with great picture ...    None
# 3  Great value. I was trying to get a P1 model, I...    None
# 4  Easy installation; crisp, clear picture. Just ...    None

# %%
import pandas as pd
import numpy as np 
import spacy
import string 
import seaborn as sns
from nltk import PorterStemmer
from matplotlib.pyplot import imread
from matplotlib import pyplot as plt 
from wordcloud import wordcloud
from nltk.corpus import stopwords
# %matplotlib inline
import re
# !pip install textblob
from textblob import TextBlob
# Out:
# ...
#      ------------------------------------ 636.8/636.8 kB 955.1 kB/s eta 0:00:00
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Saimani\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def deEmojify(inputString):
    return inputString.encode('ascii', 'ignore').decode('ascii')

# %%
STOPWORDS=stopwords.words("english")

# %%
def clean_text(text):
    ps=PorterStemmer()
    
    text=deEmojify(text) # remove emojis
    text_cleaned="".join([x for x in text if x not in string.punctuation]) # remove punctuation
    
    text_cleaned=re.sub(' +', ' ', text_cleaned) # remove extra white spaces
    text_cleaned=text_cleaned.lower() # converting to lowercase
    tokens=text_cleaned.split(" ")
    tokens=[token for token in tokens if token not in STOPWORDS] # Taking only those words which are not stopwords
    text_cleaned=" ".join([ps.stem(token) for token in tokens])
    
    
    return text_cleaned

# %%
df['cleaned_reviews']=df['review'].apply(lambda x:clean_text(x))

# %%
df.sample(5)
# Out:
#                                             TimeStamp ReviewTitle  \
# 7    Reviewed in the United States on 28 October 2022        None
# 27   Reviewed in the United States 🇺🇸 on 5 April 2022        None
# 26  Reviewed in the United States 🇺🇸 on 25 March 2022        None
# 25   Reviewed in the United States 🇺🇸 on 13 June 2022        None
# 42  Reviewed in the United States 🇺🇸 on 14 Septemb...        None
#
#                                                review ratings  \
# 7   Excellent packaging, quick arrival, everything...    None
# 27  This triple monitor extender is very portable ...    None
# 26  This product met my expectation.Very simple to...    None
# 25  This product is a straightforward plug-in and ...    None
# 42  I was excited to receive this product, but the...    None
#
#                                       cleaned_reviews
# 7   excel packag quick arriv everyth need packag s...
# 27  tripl monitor extend portabl stabl turn one la...
# ...

# %% [markdown]
# ## WorldCloud

# %%
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    plt.figure(figsize=(40,30))
    plt.imshow(wordcloud)
    plt.axis('off')
from wordcloud import WordCloud
wordcloud = WordCloud(width=3000,height=2000,background_color='black',max_words=50,
                   colormap='Set1')
wordcloud = wordcloud.generate(' '.join(df['cleaned_reviews'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in the reviews")
plt.axis('off')
plt.show()

# %% [markdown]
# ## sentimental analysis

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df['Subjectivity']=pd.DataFrame(df.review.apply(lambda x: getSubjectivity(x)))

# %%
df['Polarity']=pd.DataFrame(df.review.apply(lambda x: getPolarity(x)))

# %%
df.head()
# Out:
#                                            TimeStamp ReviewTitle  \
# 0   Reviewed in the United States on 21 January 2023        None
# 1   Reviewed in the United States on 25 January 2023        None
# 2   Reviewed in the United States on 12 October 2022        None
# 3  Reviewed in the United States on 17 November 2022        None
# 4    Reviewed in the United States on 6 January 2023        None
#
#                                               review ratings  \
# 0  First let me start this by saying I am not the...    None
# 1  The monitors connect consistently well to my D...    None
# 2  This is an awesome product with great picture ...    None
# 3  Great value. I was trying to get a P1 model, I...    None
# 4  Easy installation; crisp, clear picture. Just ...    None
#
#                                      cleaned_reviews  Subjectivity  Polarity
# 0  first let start say tech savvi individu know e...      0.544333  0.197500
# ...

# %%
def sentiment_category(score):
    if score >= 0.05:
        return "positive"
    elif score <= -0.05:
        return "negative"
    else:
        return "neutral"

# %%
df['review_category']=df['Polarity'].apply(lambda x:sentiment_category(x))

# %%
df.sample(5)
# Out:
#                                             TimeStamp ReviewTitle  \
# 44   Reviewed in the United States 🇺🇸 on 26 July 2022        None
# 32    Reviewed in the United States 🇺🇸 on 1 June 2022        None
# 26  Reviewed in the United States 🇺🇸 on 25 March 2022        None
# 31  Reviewed in the United States 🇺🇸 on 8 January ...        None
# 17  Reviewed in the United States 🇺🇸 on 28 October...        None
#
#                                                review ratings  \
# 44  I ordered these so I could work remotely while...    None
# 32                      The media could not be loa...    None
# 26  This product met my expectation.Very simple to...    None
# 31  WE DO NOT HAVE TIME TO BE RETURNING PRODUCTS. ...    None
# 17  Excellent packaging, quick arrival, everything...    None
#
#                                       cleaned_reviews  Subjectivity  Polarity  \
# 44  order could work remot daughter receiv treatme...      0.566667  0.133333
# ...

# %%
sns.countplot(df['review_category']).set_title("Distribution of Reviews Category")
# Out:
# C:\Users\Saimani\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Reviews Category')

# %%
#positive reviews wordcloud
wordcloud = WordCloud(height=2000, width=2000, background_color='pink')
wordcloud = wordcloud.generate(' '.join(df.loc[df['review_category']=='positive','cleaned_reviews'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in positive customer comments")
plt.axis('off')
plt.show()

# %%
#negative revies wordcloud
wordcloud = WordCloud(height=2000, width=2000, background_color='green')
wordcloud = wordcloud.generate(' '.join(df.loc[df['review_category']=='negative','cleaned_reviews'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in negative customer comments")
plt.axis('off')
plt.show()

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------
